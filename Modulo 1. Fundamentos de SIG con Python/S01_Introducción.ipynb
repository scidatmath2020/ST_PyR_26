# %% [markdown]
# # Titulo: Empezando con Google Colab
# ## Diplomado: Geoestadística y análisis espacial
# ### Docente: Alexis Adonai Morales Alberto
# ### SciData
#
# Este cuaderno muestra como debemos concetar nuestro google drive a  colab para futuras sesiones del diplomado.

# %%
# Configurando google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Acceder a directorio especificado

import os

ruta_carpeta = '/content/drive/MyDrive/SciData/GEOAES_25/Mapas/México_ent/'

# %%
# Cargar el mapa

import geopandas as gpd

Mapa = gpd.read_file(ruta_carpeta + '00ent.shp')

# %%
Mapa.head(5)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
